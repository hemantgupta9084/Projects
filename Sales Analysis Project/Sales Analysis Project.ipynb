# %% [markdown]
# ### Import Necessary Libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %% [markdown]
# ### Assign Path Variable to Path of Data

# %%
base_path = r"C:\PDA\PDA 26-Aug-2022\Practice Files\SalesData"

# %% [markdown]
# ### List all files from the directory

# %% [markdown]
# #### To get all files from a specific directory , we can use listdir() method.

# %%
files = os.listdir(base_path)
files
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %% [markdown]
# #### Let us go through one-month data first , to know things better.

# %%
one_month = pd.read_csv(rf"{base_path}\Sales_April_2019.csv")
one_month.head(3)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
#
#        Order Date                   Purchase Address
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001
# 1             NaN                                NaN
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215

# %% [markdown]
# ### Merging 12 months of sales data in a single file:

# %% [markdown]
# #### To Calculate and Analyze Company Sales Data, We must merge all 12 CSV files into one.

# %% [markdown]
# #### Now we need to concat all these file in a single file, for that we need to create an empty DataFrame and concat all sales file.

# %%
Sales_Data = pd.DataFrame()  #Empty DataFrame

for file in files:  #Iteration In Sales Files
    monthly_data = pd.read_csv(rf"{base_path}\{file}")  #Read File
    Sales_Data = pd.concat([Sales_Data,monthly_data])  #Concatenate File

Sales_Data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %% [markdown]
# # DATA UNDERSTANDING

# %% [markdown]
# #### #Top 5 Rows

# %%
Sales_Data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# #### #Find Shape

# %%
Sales_Data.shape
# Out:
# (186850, 6)

# %% [markdown]
# #### #Find Information

# %%
Sales_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186850 entries, 0 to 11685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 10.0+ MB

# %% [markdown]
# #### #Find Columns Name

# %%
Sales_Data.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %% [markdown]
# #### #Find Data Types

# %%
Sales_Data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
Sales_Data.select_dtypes(include="object")
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %% [markdown]
# #### #Statistical Summary

# %%
Sales_Data.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# #### #Find Duplicate Rows

# %%
Sales_Data.duplicated().sum()
# Out:
# 1162

# %% [markdown]
# #### #Drop Duplicate Rows

# %%
Sales_Data.drop_duplicates(inplace=True)
Sales_Data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### #Find Null Values

# %%
Sales_Data.isna().sum()
# Out:
# Order ID            1
# Product             1
# Quantity Ordered    1
# Price Each          1
# Order Date          1
# Purchase Address    1
# dtype: int64

# %%
Sales_Data.loc[Sales_Data.isna().any(axis=1)]
# Out:
#   Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1      NaN     NaN              NaN        NaN        NaN              NaN

# %% [markdown]
# #### #Drop null Values

# %%
Sales_Data.dropna(inplace=True)
Sales_Data.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %% [markdown]
# ###  There is some unknown string named as 'Order Date' in our Dataset.

# %% [markdown]
# #### Removing rows based on some unknown string

# %%
Sales_Data = Sales_Data.loc[Sales_Data["Order Date"] !="Order Date"]
Sales_Data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %% [markdown]
# ### Change the Data type of columns (to_numeric, to_datetime, astype)

# %%
Sales_Data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
Sales_Data["Order Date"] = pd.to_datetime(Sales_Data["Order Date"])
Sales_Data["Quantity Ordered"] = pd.to_numeric(Sales_Data["Quantity Ordered"])
Sales_Data["Price Each"] = Sales_Data["Price Each"].astype("float")
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_7912\1508150487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_Data["Order Date"] = pd.to_datetime(Sales_Data["Order Date"])
# C:\Users\varsh\AppData\Local\Temp\ipykernel_7912\1508150487.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_Data["Quantity Ordered"] = pd.to_numeric(Sales_Data["Quantity Ordered"])
# C:\Users\varsh\AppData\Local\Temp\ipykernel_7912\1508150487.py:3: SettingWithCopyWarning:
# ...

# %%
# After Change Data Types
Sales_Data.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# dtype: object

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
Sales_Data
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       176558        USB-C Charging Cable                 2       11.95
# 2       176559  Bose SoundSport Headphones                 1       99.99
# 3       176560                Google Phone                 1      600.00
# 4       176560            Wired Headphones                 1       11.99
# 5       176561            Wired Headphones                 1       11.99
# ...        ...                         ...               ...         ...
# 11681   259353      AAA Batteries (4-pack)                 3        2.99
# 11682   259354                      iPhone                 1      700.00
# 11683   259355                      iPhone                 1      700.00
# 11684   259356      34in Ultrawide Monitor                 1      379.99
# 11685   259357        USB-C Charging Cable                 1       11.95
#
#                Order Date                         Purchase Address
# ...

# %% [markdown]
# ## ***What was the best month for sales? How much was earned that month?***

# %% [markdown]
# ### Add month Column

# %% [markdown]
# #### To add month column , all we need to do is to use date time methods.

# %%
Sales_Data["month_name"] = Sales_Data["Order Date"].dt.month_name()
Sales_Data["month"] = Sales_Data["Order Date"].dt.month
Sales_Data.head(3)
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_7912\341940711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_Data["month_name"] = Sales_Data["Order Date"].dt.month_name()
# C:\Users\varsh\AppData\Local\Temp\ipykernel_7912\341940711.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_Data["month"] = Sales_Data["Order Date"].dt.month
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# ...

# %% [markdown]
# #### In This DataFrame , There are Two columns 'Price Each' and 'Quantity Ordered'.  But we do not have Total Sale Value (TSV), We should also add a calculated column Total Sale Value. Let's do it first.

# %%
Sales_Data["Total Sale Value"] = Sales_Data["Quantity Ordered"]*Sales_Data["Price Each"]
Sales_Data.head(5)
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_7912\3480398540.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_Data["Total Sale Value"] = Sales_Data["Quantity Ordered"]*Sales_Data["Price Each"]
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address month_name  month  \
# ...

# %% [markdown]
# ### Now we can easily use groupby method to find maximum sales value.

# %%
Best_month_Sale = Sales_Data.groupby(["month","month_name"])["Total Sale Value"].sum()
Best_month_Sale = Best_month_Sale.reset_index()
Best_month_Sale
# Out:
#     month month_name  Total Sale Value
# 0       1    January        1821413.16
# 1       2   February        2200078.08
# 2       3      March        2804973.35
# 3       4      April        3389217.98
# 4       5        May        3150616.23
# 5       6       June        2576280.15
# 6       7       July        2646461.32
# 7       8     August        2241083.37
# 8       9  September        2094465.69
# 9      10    October        3734777.86
# 10     11   November        3197875.05
# 11     12   December        4608295.70

# %%
## Best month Sale is-
Best_month_Sale.loc[Best_month_Sale["Total Sale Value"] == Best_month_Sale["Total Sale Value"].max()]
# Out:
#     month month_name  Total Sale Value
# 11     12   December         4608295.7

# %%
z =Best_month_Sale["Total Sale Value"].max()
print(f"Total Sale Value In December: {z}")
# Out:
# Total Sale Value In December: 4608295.7

# %% [markdown]
# ##### December is a Festival month , the biggest thing is December is Christmas, So people spend money and manby that is the reason for december is best month for sales.

# %% [markdown]
# ### Plot The Data

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=Best_month_Sale,x="month_name",y="Total Sale Value")
plt.xticks(weight="bold")
plt.yticks(weight="bold")
plt.xlabel("month_name",weight = "bold",labelpad=10,fontsize=12)
plt.ylabel("Total Sale Value",weight = "bold",labelpad=10,fontsize=12)
plt.show()

# %% [markdown]
# ## ***What city sold the most product?***

# %% [markdown]
# #### There is no City Column in our Dataset, But you can see Purchase Address ,where City is mentioned in middle, we can use Purchase address column and create a City Column.

# %%
Sales_Data["City"] = Sales_Data["Purchase Address"].str.split(",",expand=True)[1]
Sales_Data.head(3)
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_7912\4175525600.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_Data["City"] = Sales_Data["Purchase Address"].str.split(",",expand=True)[1]
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
#
#            Order Date                      Purchase Address month_name  month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      April      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      April      4
# ...

# %% [markdown]
# #### Now we can groupby City and Calculate Total Quantity Ordered.

# %%
best_sale_city = Sales_Data.groupby("City")["Quantity Ordered"].sum().sort_values()
best_sale_city = best_sale_city.reset_index()
best_sale_city
# Out:
#              City  Quantity Ordered
# 0          Austin             11137
# 1        Portland             14037
# 2         Seattle             16534
# 3         Atlanta             16584
# 4          Dallas             16707
# 5          Boston             22494
# 6   New York City             27903
# 7     Los Angeles             33247
# 8   San Francisco             50169

# %%
# City sold the most product is -
best_sale_city[best_sale_city["Quantity Ordered"] == best_sale_city["Quantity Ordered"].max()]
# Out:
#              City  Quantity Ordered
# 8   San Francisco             50169

# %%
n =best_sale_city["Quantity Ordered"].max()
print(f"San Francisco city sold the most product: {n}")
# Out:
# San Francisco city sold the most product: 50169

# %% [markdown]
# ### Plot The Data

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=best_sale_city,x="City",y="Quantity Ordered")
plt.xticks(weight="bold")
plt.yticks(weight="bold")
plt.xlabel("City",weight = "bold",labelpad=12,fontsize=14)
plt.ylabel("Quantity Ordered",weight = "bold",labelpad=12,fontsize=14)
plt.show()

# %% [markdown]
# ## ***What time should we display advertisements to maximize the likelihood of customer’s buying product?***

# %% [markdown]
# #### Because we need to work on time, let's create Hour Column.

# %%
Sales_Data["Hour"] = Sales_Data["Order Date"].dt.hour
Sales_Data.head(3)
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_7912\506862427.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sales_Data["Hour"] = Sales_Data["Order Date"].dt.hour
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
#
#            Order Date                      Purchase Address month_name  month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      April      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      April      4
# ...

# %% [markdown]
# #### Let us see what time most people bought ?

# %%
most_time_bought = Sales_Data.groupby("Hour")["Total Sale Value"].sum()
most_time_bought = most_time_bought.reset_index()
most_time_bought
# Out:
#     Hour  Total Sale Value
# 0      0         713548.66
# 1      1         460563.90
# 2      2         234839.45
# 3      3         145742.94
# 4      4         162546.07
# 5      5         230664.87
# 6      6         447963.01
# 7      7         744067.32
# 8      8        1192309.20
# 9      9        1638784.04
# 10    10        1942988.08
# 11    11        2296619.84
# 12    12        2314359.85
# 13    13        2152369.98
# 14    14        2082513.70
# 15    15        1940623.20
# 16    16        1902523.20
# 17    17        2126553.97
# 18    18        2218374.01
# 19    19        2411971.14
# 20    20        2280784.36
# 21    21        2040790.48
# 22    22        1606243.85
# 23    23        1177792.82

# %%
# What time most people bought are -
most_time_bought[most_time_bought["Total Sale Value"]==most_time_bought["Total Sale Value"].max()]
# Out:
#     Hour  Total Sale Value
# 19    19        2411971.14

# %% [markdown]
# ### Plot The Data

# %%
plt.figure(figsize=(15,7))
sns.lineplot(data=most_time_bought,x="Hour",y="Total Sale Value",marker ="*")
plt.xticks(np.arange(0,24), weight="bold",fontsize = 12)
plt.yticks(weight="bold")
plt.xlabel("Hour",weight = "bold",labelpad=10,fontsize=12)
plt.ylabel("Total Sale Value",weight = "bold",labelpad=10,fontsize=12)
plt.show()

# %% [markdown]
# ##  ***What products are most often sold together?***

# %% [markdown]
# #### This is going to be a tricky business. Before diving into the problem, let us understand the problem.
# #### What Products are most often sold together gives a very important insight that helps company lure customers into spending more and generate more profit.
# #### You must have seen Amazon's Customer Who Bought this item also bought this Item. We are going to do something like this.
# #### Let's try to solve this problem Step by step :

# %% [markdown]
# ### Duplicate Order ID :

# %% [markdown]
# #### Same Order ID for different products suggests customer bought different products Together in Our Data. Let us look for Duplicate OrderId Products:

# %%
# All Duplicate Order ID 
Duplicate_Order = Sales_Data.loc[Sales_Data["Order ID"].duplicated(keep=False)]
Duplicate_Order
# Out:
#       Order ID                 Product  Quantity Ordered  Price Each  \
# 3       176560            Google Phone                 1      600.00
# 4       176560        Wired Headphones                 1       11.99
# 18      176574            Google Phone                 1      600.00
# 19      176574    USB-C Charging Cable                 1       11.95
# 32      176586  AAA Batteries (4-pack)                 2        2.99
# ...        ...                     ...               ...         ...
# 11628   259303   AA Batteries (4-pack)                 1        3.84
# 11639   259314        Wired Headphones                 1       11.99
# 11640   259314  AAA Batteries (4-pack)                 2        2.99
# 11677   259350            Google Phone                 1      600.00
# 11678   259350    USB-C Charging Cable                 1       11.95
#
#                Order Date                        Purchase Address month_name  \
# ...

# %% [markdown]
# ### Group Different Products With Same Order ID

# %% [markdown]
# #### Let's create a new column that contains different Products with the same Order ID. We can do this with the help of transform method.

# %%
Duplicate_Order["Grouped"] = Duplicate_Order.groupby("Order ID")["Product"].transform(lambda x:",".join(x))
Duplicate_Order
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_7912\3968399332.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Duplicate_Order["Grouped"] = Duplicate_Order.groupby("Order ID")["Product"].transform(lambda x:",".join(x))
#       Order ID                 Product  Quantity Ordered  Price Each  \
# 3       176560            Google Phone                 1      600.00
# 4       176560        Wired Headphones                 1       11.99
# 18      176574            Google Phone                 1      600.00
# 19      176574    USB-C Charging Cable                 1       11.95
# 32      176586  AAA Batteries (4-pack)                 2        2.99
# ...        ...                     ...               ...         ...
# ...

# %% [markdown]
# #### counting-unique-pairs-of-numbers-

# %%
Duplicate_Order.drop_duplicates(subset="Order ID",inplace=True)
Duplicate_Order
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_7912\451091131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Duplicate_Order.drop_duplicates(subset="Order ID",inplace=True)
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 3       176560              Google Phone                 1      600.00
# 18      176574              Google Phone                 1      600.00
# 32      176586    AAA Batteries (4-pack)                 2        2.99
# 119     176672  Lightning Charging Cable                 1       14.95
# 129     176681  Apple Airpods Headphones                 1      150.00
# ...        ...                       ...               ...         ...
# 11597   259277                    iPhone                 1      700.00
# ...

# %%
Duplicate_Order = Duplicate_Order["Grouped"].value_counts().reset_index()
Duplicate_Order.rename(columns={"index":"Products","Grouped":"Products Count"},inplace=True)
Duplicate_Order
# Out:
#                                              Products  Products Count
# 0                     iPhone,Lightning Charging Cable             886
# 1                   Google Phone,USB-C Charging Cable             857
# 2                             iPhone,Wired Headphones             361
# 3                Vareebadd Phone,USB-C Charging Cable             312
# 4                       Google Phone,Wired Headphones             303
# ..                                                ...             ...
# 345               34in Ultrawide Monitor,20in Monitor               1
# 346  Google Phone,Wired Headphones,Macbook Pro Laptop               1
# 347                          LG Dryer,Vareebadd Phone               1
# 348               20in Monitor,34in Ultrawide Monitor               1
# 349          LG Washing Machine,AA Batteries (4-pack)               1
#
# [350 rows x 2 columns]

# %%
Duplicate_Order = Duplicate_Order.head(10)
Duplicate_Order
# Out:
#                                             Products  Products Count
# 0                    iPhone,Lightning Charging Cable             886
# 1                  Google Phone,USB-C Charging Cable             857
# 2                            iPhone,Wired Headphones             361
# 3               Vareebadd Phone,USB-C Charging Cable             312
# 4                      Google Phone,Wired Headphones             303
# 5                    iPhone,Apple Airpods Headphones             286
# 6            Google Phone,Bose SoundSport Headphones             161
# 7                   Vareebadd Phone,Wired Headphones             104
# 8  Google Phone,USB-C Charging Cable,Wired Headph...              79
# 9         Vareebadd Phone,Bose SoundSport Headphones              60

# %%
m = Duplicate_Order["Products"]
n = Duplicate_Order["Products Count"]

# %% [markdown]
# ### Plot The Data

# %%
plt.figure(figsize=(12,6))
plt.bar(m,n)
plt.xticks(rotation=90 ,weight="bold")
plt.yticks(weight="bold")
plt.xlabel("Products",weight = "bold",fontsize=15)
plt.ylabel("Products Count",weight = "bold",labelpad=10,fontsize=12)

for i in range(len(m)):
    plt.annotate(f"{n[i]}",(m[i],n[i]),weight="bold",ha="center",va="bottom",color="red")
plt.show()

# %% [markdown]
# ## ***What product sold the most? When do you think it sold the most?***

# %% [markdown]
# #### This is pretty simple , we will group all product and calculate quantity ordered.

# %%
most_Sold_Product = Sales_Data.groupby("Product")["Quantity Ordered"].sum().sort_values().reset_index()
most_Sold_Product
# Out:
#                        Product  Quantity Ordered
# 0                     LG Dryer               646
# 1           LG Washing Machine               666
# 2              Vareebadd Phone              2068
# 3                 20in Monitor              4126
# 4              ThinkPad Laptop              4128
# 5           Macbook Pro Laptop              4725
# 6                Flatscreen TV              4813
# 7                 Google Phone              5529
# 8       34in Ultrawide Monitor              6192
# 9       27in 4K Gaming Monitor              6239
# 10                      iPhone              6847
# 11            27in FHD Monitor              7541
# 12  Bose SoundSport Headphones             13430
# 13    Apple Airpods Headphones             15637
# 14            Wired Headphones             20524
# 15    Lightning Charging Cable             23169
# 16        USB-C Charging Cable             23931
# 17       AA Batteries (4-pack)             27615
# ...

# %%
m = most_Sold_Product["Product"]
n = most_Sold_Product["Quantity Ordered"]

# %% [markdown]
# ### Plot The Data

# %%
plt.figure(figsize=(12,6))
plt.bar(m,n)
plt.xticks(rotation=90 ,weight="bold")
plt.yticks(weight="bold")
plt.xlabel("Product",weight = "bold",fontsize=15)
plt.ylabel("Quantity Ordered",weight = "bold",labelpad=10,fontsize=14)

for i in range(len(m)):
    plt.annotate(f"{n[i]}",(m[i],n[i]),weight="bold",ha="center",va="bottom",color="red")
plt.show()
